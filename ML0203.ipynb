# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

import statsmodels.api as sm
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
from sklearn.preprocessing import OneHotEncoder

# %%
df = pd.read_csv(r"C:\Users\sarad\OneDrive\Nutrition__Physical_Activity__and_Obesity_-_Behavioral_Risk_Factor_Surveillance_System.csv")
df
# Out:
#        YearStart  YearEnd LocationAbbr    LocationDesc  \
# 0           2011     2011           AL         Alabama
# 1           2011     2011           AL         Alabama
# 2           2011     2011           AL         Alabama
# 3           2011     2011           AL         Alabama
# 4           2011     2011           AL         Alabama
# ...          ...      ...          ...             ...
# 53387       2016     2016           VI  Virgin Islands
# 53388       2016     2016           VI  Virgin Islands
# 53389       2016     2016           VI  Virgin Islands
# 53390       2016     2016           VI  Virgin Islands
# 53391       2016     2016           VI  Virgin Islands
#
#                                        Datasource                    Class  \
# 0      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# ...                                           ...                      ...
# 53387  Behavioral Risk Factor Surveillance System        Physical Activity
# 53388  Behavioral Risk Factor Surveillance System        Physical Activity
# 53389  Behavioral Risk Factor Surveillance System        Physical Activity
# 53390  Behavioral Risk Factor Surveillance System        Physical Activity
# 53391  Behavioral Risk Factor Surveillance System        Physical Activity
#
#                               Topic  \
# 0           Obesity / Weight Status
# 1           Obesity / Weight Status
# 2           Obesity / Weight Status
# 3           Obesity / Weight Status
# 4           Obesity / Weight Status
# ...                             ...
# 53387  Physical Activity - Behavior
# 53388  Physical Activity - Behavior
# 53389  Physical Activity - Behavior
# 53390  Physical Activity - Behavior
# 53391  Physical Activity - Behavior
#
#                                                 Question  Data_Value_Unit  \
# 0      Percent of adults aged 18 years and older who ...              NaN
# 1      Percent of adults aged 18 years and older who ...              NaN
# 2      Percent of adults aged 18 years and older who ...              NaN
# 3      Percent of adults aged 18 years and older who ...              NaN
# 4      Percent of adults aged 18 years and older who ...              NaN
# ...                                                  ...              ...
# 53387  Percent of adults who engage in no leisure-tim...              NaN
# 53388  Percent of adults who engage in no leisure-tim...              NaN
# 53389  Percent of adults who engage in no leisure-tim...              NaN
# 53390  Percent of adults who engage in no leisure-tim...              NaN
# 53391  Percent of adults who engage in no leisure-tim...              NaN
#
#       Data_Value_Type  ...                              GeoLocation  ClassID  \
# 0               Value  ...  (32.84057112200048, -86.63186076199969)      OWS
# 1               Value  ...  (32.84057112200048, -86.63186076199969)      OWS
# 2               Value  ...  (32.84057112200048, -86.63186076199969)      OWS
# 3               Value  ...  (32.84057112200048, -86.63186076199969)      OWS
# 4               Value  ...  (32.84057112200048, -86.63186076199969)      OWS
# ...               ...  ...                                      ...      ...
# 53387           Value  ...                  (18.335765, -64.896335)       PA
# 53388           Value  ...                  (18.335765, -64.896335)       PA
# 53389           Value  ...                  (18.335765, -64.896335)       PA
# 53390           Value  ...                  (18.335765, -64.896335)       PA
# 53391           Value  ...                  (18.335765, -64.896335)       PA
#
#       TopicID QuestionID  DataValueTypeID  LocationID  \
# 0        OWS1       Q036            VALUE           1
# 1        OWS1       Q036            VALUE           1
# 2        OWS1       Q036            VALUE           1
# 3        OWS1       Q036            VALUE           1
# 4        OWS1       Q036            VALUE           1
# ...       ...        ...              ...         ...
# 53387     PA1       Q047            VALUE          78
# 53388     PA1       Q047            VALUE          78
# 53389     PA1       Q047            VALUE          78
# 53390     PA1       Q047            VALUE          78
# 53391     PA1       Q047            VALUE          78
#
#        StratificationCategory1                Stratification1  \
# 0                        Total                          Total
# 1                       Gender                           Male
# 2                       Gender                         Female
# 3                    Education          Less than high school
# 4                    Education           High school graduate
# ...                        ...                            ...
# 53387           Race/Ethnicity                          Asian
# 53388           Race/Ethnicity      Hawaiian/Pacific Islander
# 53389           Race/Ethnicity  American Indian/Alaska Native
# 53390           Race/Ethnicity                2 or more races
# 53391           Race/Ethnicity                          Other
#
#       StratificationCategoryId1 StratificationID1
# 0                           OVR           OVERALL
# 1                           GEN              MALE
# 2                           GEN            FEMALE
# 3                           EDU             EDUHS
# 4                           EDU         EDUHSGRAD
# ...                         ...               ...
# 53387                      RACE           RACEASN
# 53388                      RACE           RACEHPI
# 53389                      RACE           RACENAA
# 53390                      RACE         RACE2PLUS
# 53391                      RACE           RACEOTH
#
# [53392 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53392 entries, 0 to 53391
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   YearStart                   53392 non-null  int64
#  1   YearEnd                     53392 non-null  int64
#  2   LocationAbbr                53392 non-null  object
#  3   LocationDesc                53392 non-null  object
#  4   Datasource                  53392 non-null  object
#  5   Class                       53392 non-null  object
#  6   Topic                       53392 non-null  object
#  7   Question                    53392 non-null  object
#  8   Data_Value_Unit             0 non-null      float64
#  9   Data_Value_Type             53392 non-null  object
#  10  Data_Value                  48346 non-null  float64
#  11  Data_Value_Alt              48346 non-null  float64
#  12  Data_Value_Footnote_Symbol  5046 non-null   object
#  13  Data_Value_Footnote         5046 non-null   object
#  14  Low_Confidence_Limit        48346 non-null  float64
#  15  High_Confidence_Limit       48346 non-null  float64
#  16  Sample_Size                 48346 non-null  float64
#  17  Total                       1907 non-null   object
#  18  Age(years)                  11438 non-null  object
#  19  Education                   7628 non-null   object
#  20  Gender                      3814 non-null   object
#  21  Income                      13349 non-null  object
#  22  Race/Ethnicity              15256 non-null  object
#  23  GeoLocation                 52384 non-null  object
#  24  ClassID                     53392 non-null  object
#  25  TopicID                     53392 non-null  object
#  26  QuestionID                  53392 non-null  object
#  27  DataValueTypeID             53392 non-null  object
#  28  LocationID                  53392 non-null  int64
#  29  StratificationCategory1     53392 non-null  object
#  30  Stratification1             53392 non-null  object
#  31  StratificationCategoryId1   53392 non-null  object
#  32  StratificationID1           53392 non-null  object
# dtypes: float64(6), int64(3), object(24)
# memory usage: 13.4+ MB

# %%
df = df.drop(['Low_Confidence_Limit','High_Confidence_Limit ', 'Total', 'Data_Value_Alt', 'YearEnd','Topic','Class','Datasource','Data_Value_Unit','QuestionID','ClassID','TopicID','DataValueTypeID','Data_Value_Type','Data_Value_Footnote_Symbol','Data_Value_Footnote','StratificationCategoryId1','StratificationID1'],1);
df = df.drop(['GeoLocation', 'Question', 'StratificationCategory1', 'Stratification1', 'Gender'],1)
# Out:
# C:\Users\sarad\AppData\Local\Temp\ipykernel_60908\3924928650.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop(['Low_Confidence_Limit','High_Confidence_Limit ', 'Total', 'Data_Value_Alt', 'YearEnd','Topic','Class','Datasource','Data_Value_Unit','QuestionID','ClassID','TopicID','DataValueTypeID','Data_Value_Type','Data_Value_Footnote_Symbol','Data_Value_Footnote','StratificationCategoryId1','StratificationID1'],1);
# C:\Users\sarad\AppData\Local\Temp\ipykernel_60908\3924928650.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop(['GeoLocation', 'Question', 'StratificationCategory1', 'Stratification1', 'Gender'],1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53392 entries, 0 to 53391
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   YearStart       53392 non-null  int64
#  1   LocationAbbr    53392 non-null  object
#  2   LocationDesc    53392 non-null  object
#  3   Data_Value      48346 non-null  float64
#  4   Sample_Size     48346 non-null  float64
#  5   Age(years)      11438 non-null  object
#  6   Education       7628 non-null   object
#  7   Income          13349 non-null  object
#  8   Race/Ethnicity  15256 non-null  object
#  9   LocationID      53392 non-null  int64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 4.1+ MB

# %%
df=df.dropna(subset=['Education'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7628 entries, 3 to 53370
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   YearStart       7628 non-null   int64
#  1   LocationAbbr    7628 non-null   object
#  2   LocationDesc    7628 non-null   object
#  3   Data_Value      7628 non-null   float64
#  4   Sample_Size     7628 non-null   float64
#  5   Age(years)      0 non-null      object
#  6   Education       7628 non-null   object
#  7   Income          0 non-null      object
#  8   Race/Ethnicity  0 non-null      object
#  9   LocationID      7628 non-null   int64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 655.5+ KB

# %%
def lower_case_column_names(df):
    df.columns=[i.lower() for i in df.columns]
    return df

# %%
df=lower_case_column_names(df)
df
# Out:
#        yearstart locationabbr    locationdesc  data_value  sample_size  \
# 3           2011           AL         Alabama        33.6       1153.0
# 4           2011           AL         Alabama        32.8       2402.0
# 5           2011           AL         Alabama        33.8       1925.0
# 6           2011           AL         Alabama        26.4       1812.0
# 31          2011           AL         Alabama        33.2       1153.0
# ...          ...          ...             ...         ...          ...
# 53343       2016           PR     Puerto Rico        33.9       1735.0
# 53367       2016           VI  Virgin Islands        29.2        238.0
# 53368       2016           VI  Virgin Islands        26.9        394.0
# 53369       2016           VI  Virgin Islands        31.2        230.0
# 53370       2016           VI  Virgin Islands        16.4        378.0
#
#       age(years)                         education income race/ethnicity  \
# 3            NaN             Less than high school    NaN            NaN
# 4            NaN              High school graduate    NaN            NaN
# 5            NaN  Some college or technical school    NaN            NaN
# 6            NaN                  College graduate    NaN            NaN
# 31           NaN             Less than high school    NaN            NaN
# ...          ...                               ...    ...            ...
# 53343        NaN                  College graduate    NaN            NaN
# 53367        NaN             Less than high school    NaN            NaN
# 53368        NaN              High school graduate    NaN            NaN
# 53369        NaN  Some college or technical school    NaN            NaN
# 53370        NaN                  College graduate    NaN            NaN
#
#        locationid
# 3               1
# 4               1
# 5               1
# 6               1
# 31              1
# ...           ...
# 53343          72
# 53367          78
# 53368          78
# 53369          78
# 53370          78
#
# [7628 rows x 10 columns]

# %%
df.dtypes
# Out:
# yearstart           int64
# locationabbr       object
# locationdesc       object
# data_value        float64
# sample_size       float64
# age(years)         object
# education          object
# income             object
# race/ethnicity     object
# locationid          int64
# dtype: object

# %%
print(df.duplicated().sum())
# Out:
# 8

# %%
df = df.drop_duplicates()

# %%
df.isna()
# Out:
#        yearstart  locationabbr  locationdesc  data_value  sample_size  \
# 3          False         False         False       False        False
# 4          False         False         False       False        False
# 5          False         False         False       False        False
# 6          False         False         False       False        False
# 31         False         False         False       False        False
# ...          ...           ...           ...         ...          ...
# 53343      False         False         False       False        False
# 53367      False         False         False       False        False
# 53368      False         False         False       False        False
# 53369      False         False         False       False        False
# 53370      False         False         False       False        False
#
#        age(years)  education  income  race/ethnicity  locationid
# 3            True      False    True            True       False
# 4            True      False    True            True       False
# 5            True      False    True            True       False
# 6            True      False    True            True       False
# 31           True      False    True            True       False
# ...           ...        ...     ...             ...         ...
# 53343        True      False    True            True       False
# 53367        True      False    True            True       False
# 53368        True      False    True            True       False
# 53369        True      False    True            True       False
# 53370        True      False    True            True       False
#
# [7620 rows x 10 columns]

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
percent_missing
# Out:
# yearstart           0.0
# locationabbr        0.0
# locationdesc        0.0
# data_value          0.0
# sample_size         0.0
# age(years)        100.0
# education           0.0
# income            100.0
# race/ethnicity    100.0
# locationid          0.0
# dtype: float64

# %%
df = df.drop(['age(years)'],1)
# Out:
# C:\Users\sarad\AppData\Local\Temp\ipykernel_60908\211770201.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop(['age(years)'],1)

# %%
def remove_outliers(df):
    for col in df.select_dtypes(include=np.number).columns:
        q1 = df[col].quantile(0.25)
        q3 = df[col].quantile(0.75)
        iqr = q3 - q1
        lower_bound = q1 - (1.5 * iqr)
        upper_bound = q3 + (1.5 * iqr)
        df.drop(df[(df[col] < lower_bound) | (df[col] > upper_bound)].index, inplace=True)

# %%
remove_outliers(df)
df
# Out:
#        yearstart locationabbr    locationdesc  data_value  sample_size  \
# 3           2011           AL         Alabama        33.6       1153.0
# 4           2011           AL         Alabama        32.8       2402.0
# 5           2011           AL         Alabama        33.8       1925.0
# 6           2011           AL         Alabama        26.4       1812.0
# 31          2011           AL         Alabama        33.2       1153.0
# ...          ...          ...             ...         ...          ...
# 53343       2016           PR     Puerto Rico        33.9       1735.0
# 53367       2016           VI  Virgin Islands        29.2        238.0
# 53368       2016           VI  Virgin Islands        26.9        394.0
# 53369       2016           VI  Virgin Islands        31.2        230.0
# 53370       2016           VI  Virgin Islands        16.4        378.0
#
#                               education income race/ethnicity  locationid
# 3                 Less than high school    NaN            NaN           1
# 4                  High school graduate    NaN            NaN           1
# 5      Some college or technical school    NaN            NaN           1
# 6                      College graduate    NaN            NaN           1
# 31                Less than high school    NaN            NaN           1
# ...                                 ...    ...            ...         ...
# 53343                  College graduate    NaN            NaN          72
# 53367             Less than high school    NaN            NaN          78
# 53368              High school graduate    NaN            NaN          78
# 53369  Some college or technical school    NaN            NaN          78
# 53370                  College graduate    NaN            NaN          78
#
# [7002 rows x 9 columns]

# %%
def standardize_text(df):
    for col in df.select_dtypes(include=['object']).columns:
        df[col] = df[col].str.lower()

# %%
standardize_text(df)
df
# Out:
#        yearstart locationabbr    locationdesc  data_value  sample_size  \
# 3           2011           al         alabama        33.6       1153.0
# 4           2011           al         alabama        32.8       2402.0
# 5           2011           al         alabama        33.8       1925.0
# 6           2011           al         alabama        26.4       1812.0
# 31          2011           al         alabama        33.2       1153.0
# ...          ...          ...             ...         ...          ...
# 53343       2016           pr     puerto rico        33.9       1735.0
# 53367       2016           vi  virgin islands        29.2        238.0
# 53368       2016           vi  virgin islands        26.9        394.0
# 53369       2016           vi  virgin islands        31.2        230.0
# 53370       2016           vi  virgin islands        16.4        378.0
#
#                               education income race/ethnicity  locationid
# 3                 less than high school    NaN            NaN           1
# 4                  high school graduate    NaN            NaN           1
# 5      some college or technical school    NaN            NaN           1
# 6                      college graduate    NaN            NaN           1
# 31                less than high school    NaN            NaN           1
# ...                                 ...    ...            ...         ...
# 53343                  college graduate    NaN            NaN          72
# 53367             less than high school    NaN            NaN          78
# 53368              high school graduate    NaN            NaN          78
# 53369  some college or technical school    NaN            NaN          78
# 53370                  college graduate    NaN            NaN          78
#
# [7002 rows x 9 columns]

# %%
numerical_columns = df.select_dtypes(include=['int', 'float']).columns
numerical = df[numerical_columns]
numerical
# Out:
#        yearstart  data_value  sample_size  locationid
# 3           2011        33.6       1153.0           1
# 4           2011        32.8       2402.0           1
# 5           2011        33.8       1925.0           1
# 6           2011        26.4       1812.0           1
# 31          2011        33.2       1153.0           1
# ...          ...         ...          ...         ...
# 53343       2016        33.9       1735.0          72
# 53367       2016        29.2        238.0          78
# 53368       2016        26.9        394.0          78
# 53369       2016        31.2        230.0          78
# 53370       2016        16.4        378.0          78
#
# [7002 rows x 4 columns]

# %%
numerical = numerical.fillna(numerical.mean())
numerical
# Out:
#        yearstart  data_value  sample_size  locationid
# 3           2011        33.6       1153.0           1
# 4           2011        32.8       2402.0           1
# 5           2011        33.8       1925.0           1
# 6           2011        26.4       1812.0           1
# 31          2011        33.2       1153.0           1
# ...          ...         ...          ...         ...
# 53343       2016        33.9       1735.0          72
# 53367       2016        29.2        238.0          78
# 53368       2016        26.9        394.0          78
# 53369       2016        31.2        230.0          78
# 53370       2016        16.4        378.0          78
#
# [7002 rows x 4 columns]

# %%
categorical_columns = df.select_dtypes(include=['object']).columns
categorical = df[categorical_columns]
categorical
# Out:
#       locationabbr    locationdesc                         education income  \
# 3               al         alabama             less than high school    NaN
# 4               al         alabama              high school graduate    NaN
# 5               al         alabama  some college or technical school    NaN
# 6               al         alabama                  college graduate    NaN
# 31              al         alabama             less than high school    NaN
# ...            ...             ...                               ...    ...
# 53343           pr     puerto rico                  college graduate    NaN
# 53367           vi  virgin islands             less than high school    NaN
# 53368           vi  virgin islands              high school graduate    NaN
# 53369           vi  virgin islands  some college or technical school    NaN
# 53370           vi  virgin islands                  college graduate    NaN
#
#       race/ethnicity
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 31               NaN
# ...              ...
# 53343            NaN
# 53367            NaN
# 53368            NaN
# 53369            NaN
# 53370            NaN
#
# [7002 rows x 5 columns]

# %%
categorical
# Out:
#       locationabbr    locationdesc                         education income  \
# 3               al         alabama             less than high school    NaN
# 4               al         alabama              high school graduate    NaN
# 5               al         alabama  some college or technical school    NaN
# 6               al         alabama                  college graduate    NaN
# 31              al         alabama             less than high school    NaN
# ...            ...             ...                               ...    ...
# 53343           pr     puerto rico                  college graduate    NaN
# 53367           vi  virgin islands             less than high school    NaN
# 53368           vi  virgin islands              high school graduate    NaN
# 53369           vi  virgin islands  some college or technical school    NaN
# 53370           vi  virgin islands                  college graduate    NaN
#
#       race/ethnicity
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 31               NaN
# ...              ...
# 53343            NaN
# 53367            NaN
# 53368            NaN
# 53369            NaN
# 53370            NaN
#
# [7002 rows x 5 columns]

# %%
categorical.columns
# Out:
# Index(['locationabbr', 'locationdesc', 'education', 'income',
#        'race/ethnicity'],
#       dtype='object')

# %%
in_map = {'less than $15,000':0, '15,000- 24,999':1, '25,000- 34,999':2,'35,000- 49,999':3, '50,000- 74,999':4,'$75,000 or greater':5, 'data not reported':6}
in_map
df['income'] = df['income'].map(in_map)

# %%
ed_map = {'less than high school': 0, 'high school graduate':1, 'some college or technical school':2,'college graduate':3}
ed_map
df['education'] = df['education'].map(ed_map)

# %%
rc_map = {'non-hispanic white': 0, 'non-hispanic black':1, 'hispanic':2,'asian':3, 'hawaiian/pacific islander':4,
       'american indian/alaska native':5, '2 or more races':6, 'other':7}
rc_map
df['race/ethnicity'] = df['race/ethnicity'].map(rc_map)

# %%
df
# Out:
#        yearstart locationabbr    locationdesc  data_value  sample_size  \
# 3           2011           al         alabama        33.6       1153.0
# 4           2011           al         alabama        32.8       2402.0
# 5           2011           al         alabama        33.8       1925.0
# 6           2011           al         alabama        26.4       1812.0
# 31          2011           al         alabama        33.2       1153.0
# ...          ...          ...             ...         ...          ...
# 53343       2016           pr     puerto rico        33.9       1735.0
# 53367       2016           vi  virgin islands        29.2        238.0
# 53368       2016           vi  virgin islands        26.9        394.0
# 53369       2016           vi  virgin islands        31.2        230.0
# 53370       2016           vi  virgin islands        16.4        378.0
#
#        education  income  race/ethnicity  locationid
# 3              0     NaN             NaN           1
# 4              1     NaN             NaN           1
# 5              2     NaN             NaN           1
# 6              3     NaN             NaN           1
# 31             0     NaN             NaN           1
# ...          ...     ...             ...         ...
# 53343          3     NaN             NaN          72
# 53367          0     NaN             NaN          78
# 53368          1     NaN             NaN          78
# 53369          2     NaN             NaN          78
# 53370          3     NaN             NaN          78
#
# [7002 rows x 9 columns]

# %%
for col in numerical.columns:
    sns.displot(numerical[col])
    plt.show()

# %%
numerical.hist(figsize=(20,15), grid=False)
plt.show()

# %%
sns.pairplot(numerical)

# %%
numerical.corr()
# Out:
#              yearstart  data_value  sample_size  locationid
# yearstart     1.000000    0.018635    -0.082100    0.045116
# data_value    0.018635    1.000000    -0.123163   -0.005925
# sample_size  -0.082100   -0.123163     1.000000    0.014645
# locationid    0.045116   -0.005925     0.014645    1.000000

# %%
corr = numerical.corr()
sns.heatmap(corr,
        xticklabels=corr.columns,
        yticklabels=corr.columns,
        annot=True, cmap='Reds')
# Out:
# <Axes: >

# %%
#X = df[['yearstart','income', 'locationid']]
X = df[['yearstart','education', 'locationid']]
y = numerical['data_value']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
X_train = pd.DataFrame(X_train)
X_test = pd.DataFrame(X_test)
X_train.head(3)
# Out:
#        yearstart  education  locationid
# 19471       2013          2          31
# 25798       2011          3          41
# 45308       2015          1          56

# %%
std_scaler=StandardScaler().fit(X_train)

X_train_scaled=std_scaler.transform(X_train)

# %%
X_test_scaled=std_scaler.transform(X_test)

# %%
print(X_train_scaled)
print("--------")
print(X_test_scaled)
# Out:
# [[-0.18686035  0.50826302  0.07746434]
#  [-1.37006781  1.41145267  0.68345429]
#  [ 0.99634711 -0.39492663  1.59243923]
#  ...
#  [ 0.99634711 -0.39492663 -0.71032261]
#  [ 0.99634711 -0.39492663  0.92585028]
#  [-1.37006781 -0.39492663  0.19866233]]
# --------
# [[ 0.99634711  1.41145267 -0.28612964]
#  [ 0.99634711 -0.39492663  0.01686534]
#  [ 0.99634711 -1.29811628 -0.28612964]
#  ...
#  [-1.37006781  1.41145267  0.13806333]
#  [-0.18686035 -1.29811628 -1.13451558]
#  [-0.18686035 -0.39492663  1.22884525]]

# %%
X_train_const_scaled = sm.add_constant(X_train_scaled) # adding a constant

model = sm.OLS(y_train, X_train_const_scaled).fit()
predictions_train = model.predict(X_train_const_scaled)

X_test_const_scaled = sm.add_constant(X_test_scaled) # adding a constant
predictions_test = model.predict(X_test_const_scaled)
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             data_value   R-squared:                       0.046
# Model:                            OLS   Adj. R-squared:                  0.046
# Method:                 Least Squares   F-statistic:                     79.19
# Date:                Sat, 29 Jul 2023   Prob (F-statistic):           5.08e-50
# Time:                        21:35:42   Log-Likelihood:                -17897.
# No. Observations:                4901   AIC:                         3.580e+04
# Df Residuals:                    4897   BIC:                         3.583e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         30.6260      0.133    229.830      0.000      30.365      30.887
# x1             0.3860      0.133      2.893      0.004       0.124       0.648
# x2            -2.0228      0.133    -15.175      0.000      -2.284      -1.761
# x3             0.0258      0.133      0.194      0.846      -0.236       0.287
# ==============================================================================
# Omnibus:                        0.454   Durbin-Watson:                   2.038
# Prob(Omnibus):                  0.797   Jarque-Bera (JB):                0.494
# Skew:                          -0.017   Prob(JB):                        0.781
# Kurtosis:                       2.965   Cond. No.                         1.06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
predictions_test
# Out:
# array([28.14808527, 31.80977722, 33.62887539, ..., 27.24571306,
#        33.15027772, 31.38443631])

# %%
print(model.rsquared_adj)
# Out:
# 0.04568431550629104

# %%
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
model.coef_
# Out:
# array([ 2.28334209e-01, -1.82693004e+00,  1.56637518e-03])

# %%
model.intercept_
# Out:
# -426.50371557828714

# %%
model.score(X_test_scaled,y_test)
# Out:
# C:\Users\sarad\Anac py\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# -2269.70377720336

# %%
y_pred=model.predict(X_test_scaled)
# Out:
# C:\Users\sarad\Anac py\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
y_test
# Out:
# 46935    17.3
# 41919    37.5
# 41269    47.8
# 49836    36.5
# 44580    37.5
#          ...
# 52020    19.3
# 36441    15.4
# 19635    25.5
# 5865      8.3
# 31613    51.9
# Name: data_value, Length: 2101, dtype: float64

# %%
y_pred
# Out:
# array([-428.85528892, -425.5546857 , -423.905096  , ..., -429.39495795,
#        -424.17659163, -425.82295403])

# %%
result=pd.DataFrame({"y_test":y_test,"y_pred":y_pred})

# %%
fig, ax = plt.subplots(1,3,figsize=(14,4))
ax[0].plot(y_pred, y_test, 'o')
ax[0].set_xlabel("y_test")
ax[0].set_ylabel("y_pred")
ax[0].set_title("Test Set -Predicted vs real")

# Get a histogram of the residuals ie: y - y_pred.  Homoscdasticity
# It resembles a normal distribution?
ax[1].hist(y_test - y_pred)
ax[1].set_xlabel("Test y-y_pred")
ax[1].set_title("Test Set Residual histogram")

ax[2].plot(y_pred,y_test - y_pred,"o")
ax[2].set_xlabel("predited")
ax[2].set_ylabel("residuals")
ax[2].set_title("Residuals by Predicted")
ax[2].plot(y_pred,np.zeros(len(y_pred)),linestyle='dashed')

# %%
sns.regplot(x='y_test',y='y_pred', data=result, scatter_kws={"color": "red"}, line_kws={"color": "black"})
# Out:
# <Axes: xlabel='y_test', ylabel='y_pred'>

# %%
mse = mse(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
adj_r2= 1 - (1-r2)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
print("Mean Squared Error:", mse)
print("R-squared:", r2)
print("Adjusted R-squared:", adj_r2)
# Out:
# Mean Squared Error: 209135.91977608835
# R-squared: -2269.70377720336
# Adjusted R-squared: -2272.9522804611615

# %%
features_importances = pd.DataFrame(data={
    'Attribute': X_train.columns,
    'Importance': abs(model.coef_)
})
features_importances = features_importances.sort_values(by='Importance', ascending=False)

# %%
features_importances
# Out:
#     Attribute  Importance
# 1   education    1.826930
# 0   yearstart    0.228334
# 2  locationid    0.001566

# %%
plt.bar(x=features_importances['Attribute'], height=features_importances['Importance'], color='#087E8B')
plt.title('Feature importances obtained from coefficients', size=15)
plt.xticks(rotation='vertical')
plt.show()
